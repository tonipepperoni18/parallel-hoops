# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# /Users/jarvis/Library/CloudStorage/GoogleDrive-toniantoine2018@gmail.com/My Drive/parallel-hoops

# %%
import pandas as pd 

nba_normalized = pd.read_csv("../DATA/processed/nba_25_26_normalized.csv")
wnba_normalized = pd.read_csv("../DATA/processed/wnba/wnba_model_normalized.csv")

# %%
nba_normalized["league"] = "NBA"
wnba_normalized["league"] = "WNBA"

nba_normalized.shape
wnba_normalized.shape
# Out:
# (111, 42)

# %%
import pandas as pd

combined_df = pd.concat(
    [nba_normalized, wnba_normalized],
    ignore_index=True
)

combined_df.shape
# Out:
# (546, 60)

# %%
combined_df.to_csv(
    "../DATA/processed/combined/25-26/combined_25_26.csv",
    index=False
)

# %%
from importlib import reload
import src.similarity_engine
reload(src.similarity_engine)
from src.similarity_engine import find_league_comps

find_league_comps(
    "Breanna Stewart",
    combined_df,
    target_league="NBA",
    top_n=20
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 6
#       2 import src.similarity_engine
#       3 reload(src.similarity_engine)
#       4 from src.similarity_engine import find_similar_players
#       5
# ----> 6 find_similar_players(
#       7     "Breanna Stewart",
#       8     combined_df[combined_df["league"] == "NBA"],
#       9     top_n=20
#
# File ~/Library/CloudStorage/GoogleDrive-toniantoine2018@gmail.com/My Drive/parallel-hoops/src/similarity_engine.py:178, in find_similar_players(player_name, df, top_n, same_position, same_league)
#     168 """
#     169 Finds the most similar players and includes category similarity scores.
#     170
#    (...)    173 - same_league=True only returns players from the same league
#     174 """
#     176 df = df.copy().reset_index(drop=True)
# --> 178 target_index = find_player_index(df, player_name)
# ...
