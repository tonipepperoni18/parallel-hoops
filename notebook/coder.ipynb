# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
nba_normalized["league"] = "NBA"
wnba_normalized["league"] = "WNBA"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nba_normalized["league"] = "NBA"
#       2 wnba_normalized["league"] = "WNBA"
#
# NameError: name 'nba_normalized' is not defined

# %%
import pandas as pd

combined_df = pd.concat(
    [nba_normalized, wnba_normalized],
    ignore_index=True
)

combined_df.shape

# %%
combined_df.to_csv(
    "DATA/processed/combined_similarity_dataset.csv",
    index=False
)

# %%
combined_df["league"].value_counts()
