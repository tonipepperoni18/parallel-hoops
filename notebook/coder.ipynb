# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# /Users/jarvis/Library/CloudStorage/GoogleDrive-toniantoine2018@gmail.com/My Drive/parallel-hoops

# %%
import pandas as pd 

nba_normalized = pd.read_csv("../DATA/processed/nba_25_26_normalized.csv")
wnba_normalized = pd.read_csv("../DATA/processed/wnba/wnba_model_normalized.csv")

# %%
nba_normalized["league"] = "NBA"
wnba_normalized["league"] = "WNBA"

nba_normalized.shape
wnba_normalized.shape
# Out:
# (111, 42)

# %%
from importlib import reload
import src.similarity_engine
reload(src.similarity_engine)
from src.similarity_engine import find_league_comps

find_league_comps(
    "Veronica Burton",
    combined_df,
    target_league="NBA",
    top_n=20
)
# Out:
#                player   tm pos league season   age     g      mp  \
# 0        James Harden  2TM  PG    NBA  25-26  36.0  70.0  2438.0
# 1      Stephon Castle  SAS  PG    NBA  25-26  21.0  68.0  2038.0
# 2        James Harden  LAC  PG    NBA  25-26  36.0  44.0  1559.0
# 3     Cade Cunningham  DET  PG    NBA  25-26  24.0  64.0  2172.0
# 4         LaMelo Ball  CHO  PG    NBA  25-26  24.0  72.0  2017.0
# 5         Deni Avdija  POR  SF    NBA  25-26  25.0  66.0  2199.0
# 6       Austin Reaves  LAL  SG    NBA  25-26  27.0  51.0  1762.0
# 7   Immanuel Quickley  TOR  PG    NBA  25-26  26.0  70.0  2231.0
# 8       Julius Randle  MIN  PF    NBA  25-26  31.0  79.0  2610.0
# 9        De'Aaron Fox  SAS  PG    NBA  25-26  28.0  72.0  2231.0
# 10        Luka Dončić  LAL  PG    NBA  25-26  26.0  64.0  2289.0
# 11       Nikola Jokić  DEN   C    NBA  25-26  30.0  65.0  2265.0
# 12        Josh Giddey  CHI  PG    NBA  25-26  23.0  54.0  1731.0
# 13   Donovan Mitchell  CLE  SG    NBA  25-26  29.0  70.0  2342.0
# 14       James Harden  CLE  PG    NBA  25-26  36.0  26.0   879.0
# 15       Jamal Murray  DEN  PG    NBA  25-26  28.0  75.0  2652.0
# 16       Tyrese Maxey  PHI  PG    NBA  25-26  25.0  70.0  2661.0
# 17      Jalen Johnson  ATL  SF    NBA  25-26  24.0  72.0  2532.0
# 18        Cam Spencer  MEM  SG    NBA  25-26  25.0  72.0  1714.0
# 19       Desmond Bane  ORL  SG    NBA  25-26  27.0  82.0  2756.0
#
#     scoring_similarity  playmaking_similarity  individual_defense_similarity  \
# 0             0.356307               0.265742                       0.404901
# 1             0.251026               0.262163                       0.361985
# 2             0.304005               0.244976                       0.392458
# 3             0.216824               0.226923                       0.598366
# 4             0.214613               0.238304                       0.382428
# 5             0.253842               0.246842                       0.343055
# 6             0.244635               0.261100                       0.423805
# 7             0.250538               0.260251                       0.341431
# 8             0.223771               0.259400                       0.387968
# 9             0.200529               0.313722                       0.440482
# 10            0.176251               0.190880                       0.463401
# 11            0.155172               0.136810                       0.742053
# 12            0.272782               0.209273                       0.366661
# 13            0.199766               0.235888                       0.410450
# 14            0.281893               0.250621                       0.340393
# 15            0.185793               0.229058                       0.299928
# 16            0.224839               0.231111                       0.375625
# 17            0.216957               0.289305                       0.420334
# 18            0.187158               0.362413                       0.328233
# 19            0.236245               0.225186                       0.425660
#
#     team_defense_similarity  impact_similarity  position_similarity  \
# 0                  0.442145           0.246483             0.355449
# 1                  0.526959           0.374794             0.348167
# 2                  0.348290           0.265825             0.317352
# 3                  0.361295           0.194778             0.316275
# 4                  0.727481           0.250149             0.285519
# 5                  0.418937           0.251271             0.332216
# 6                  0.350532           0.322361             0.390108
# 7                  0.546348           0.320938             0.324334
# 8                  0.582114           0.387911             0.252221
# 9                  0.473236           0.352391             0.271811
# 10                 0.302487           0.135191             0.307983
# 11                 0.155092           0.088633             0.271923
# 12                 0.278349           0.292788             0.365970
# 13                 0.521393           0.209979             0.390887
# 14                 0.314151           0.261354             0.364487
# 15                 0.322314           0.221320             0.269133
# 16                 0.446844           0.197595             0.275340
# 17                 0.209964           0.241021             0.255490
# 18                 0.228567           0.351448             0.375474
# 19                 0.393501           0.391208             0.312407
#
#     overall_similarity_score
# 0                   0.689224
# 1                   0.646081
# 2                   0.612448
# 3                   0.602651
# 4                   0.600796
# 5                   0.587052
# 6                   0.557408
# 7                   0.535700
# 8                   0.531785
# 9                   0.506181
# 10                  0.502080
# 11                  0.501267
# 12                  0.498512
# 13                  0.488885
# 14                  0.486810
# 15                  0.485868
# 16                  0.485792
# 17                  0.485361
# 18                  0.472776
# 19                  0.472702
